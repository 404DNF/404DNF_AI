# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/졸업논문/data/0923preprocessed/contextual_predicate.csv')

df
# Out:
#                                                  String              Type  \
# 0                    19 people buy this product per day      Social Proof
# 1                           Flash Sale ends in SHOP NOW           Urgency
# 2                 17 people have viewed this wine today      Social Proof
# 3     These cookies are usually set by our marketing...  Not Dark Pattern
# 4                                         Strip Softbox  Not Dark Pattern
# ...                                                 ...               ...
# 3195                This link will open in a new window  Not Dark Pattern
# 3196                             B-Series Truck remotes  Not Dark Pattern
# 3197                                 from Korea, Taiwan  Not Dark Pattern
# 3198                                          The best!  Not Dark Pattern
# 3199  Nice choice. Did you know you’re missing out o...      Misdirection
#
#       label               predicate
# 0         1  Activity Notifications
# ...

# %%
df['String'].value_counts()
# Out:
# String
# ★ ★ ★ ★ ★                                                                             4
# 40% OFF EVERYTHING* ENTER: 40PLT + FREE SHIPPING ON ALL ORDERS OVER $80               4
# Michael in Pontiac, United States purchased a                                         4
# FANSTASTIC DEALS HERE                                                                 3
# Customers already bought                                                              3
#                                                                                      ..
# High Arches                                                                           1
# Mitre Saws                                                                            1
# Red Tops !                                                                            1
# Nursery                                                                               1
# Brilliant! Chose what I wanted, and came a week later. Very happy with my purchase    1
# ...

# %%
df['Type'].value_counts()
# Out:
# Type
# Not Dark Pattern    1600
# Social Proof         400
# Urgency              400
# Misdirection         400
# Scarcity             400
# Name: count, dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# 1    1600
# 0    1600
# Name: count, dtype: int64

# %%
df['predicate'].value_counts()
# Out:
# predicate
# Activity Notifications              393
# Low-stock Messages                  360
# Confirmshaming                      279
# Countdown Timers                    213
# Limited-time Messages               187
# Pressured Selling                    74
# Trick Questions                      47
# High-demand Messages                 40
# Testimonials of Uncertain Origin      7
# Name: count, dtype: int64
